# %% [markdown]
# # Week 1 - Data Ingestion
#
# ## Objective
#
# The objective of this notebook is to import the raw marketing attribution dataset, inspect its structure, understand the available features, and prepare the data for cleaning and analysis.
#
# ### Dataset
# - multi_touch_attribution_data.csv
#
# ### Tasks
# - Load Dataset
# - Inspect Shape
# - View Columns
# - Check Data Types
# - Display Sample Records

# %%
import pandas as pd
import numpy as np

# Display all columns
pd.set_option("display.max_columns", None)

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
df = pd.read_csv("../data/raw/multi_touch_attribution_data.csv")

# %%
df.shape
# Out:
# (10000, 5)

# %%
df.head()
# Out:
#    User ID            Timestamp         Channel            Campaign Conversion
# 0    83281  2025-02-10 07:58:51           Email  New Product Launch         No
# 1    68071  2025-02-10 23:38:48      Search Ads         Winter Sale         No
# 2    90131  2025-02-11 10:41:07    Social Media     Brand Awareness        Yes
# 3    71026  2025-02-10 08:19:44  Direct Traffic                   -        Yes
# 4    94486  2025-02-10 15:15:46           Email         Retargeting        Yes

# %%
df.columns
# Out:
# Index(['User ID', 'Timestamp', 'Channel', 'Campaign', 'Conversion'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User ID     10000 non-null  int64
#  1   Timestamp   10000 non-null  str
#  2   Channel     10000 non-null  str
#  3   Campaign    10000 non-null  str
#  4   Conversion  10000 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 390.8 KB

# %%
attribution = pd.read_csv("../data/raw/multi_touch_attribution_data.csv")

performance = pd.read_csv("../data/raw/tech_advertising_campaigns_dataset.csv")

# %%
attribution.shape
performance.shape
# Out:
# (10000, 41)

# %%
attribution.head()
performance.head()
# Out:
#   campaign_id campaign_objective    platform ad_placement device_type  \
# 0  CAMP_00001    Lead Generation    Facebook       Search      Mobile
# 1  CAMP_00002         Engagement    Facebook         Feed      Mobile
# 2  CAMP_00003        Conversions  Google Ads         Feed      Tablet
# 3  CAMP_00004        Conversions    LinkedIn       Search     Desktop
# 4  CAMP_00005    Brand Awareness    Facebook      Stories      Mobile
#
#   operating_system creative_format creative_size ad_copy_length  \
# 0          Android            Text        728x90          Short
# 1              iOS           Image        320x50           Long
# 2              iOS           Video     1920x1080          Short
# 3              iOS        Carousel     1920x1080          Short
# 4              iOS           Image     1920x1080          Short
#
#    has_call_to_action creative_emotion  creative_age_days target_audience_age  \
# ...

# %%
attribution.columns
performance.columns
# Out:
# Index(['campaign_id', 'campaign_objective', 'platform', 'ad_placement',
#        'device_type', 'operating_system', 'creative_format', 'creative_size',
#        'ad_copy_length', 'has_call_to_action', 'creative_emotion',
#        'creative_age_days', 'target_audience_age', 'target_audience_gender',
#        'audience_interest_category', 'income_bracket', 'purchase_intent_score',
#        'retargeting_flag', 'start_date', 'quarter', 'day_of_week',
#        'hour_of_day', 'campaign_day', 'quality_score', 'actual_cpc',
#        'impressions', 'clicks', 'conversions', 'ad_spend', 'revenue',
#        'bounce_rate', 'avg_session_duration_seconds', 'pages_per_session',
#        'industry_vertical', 'budget_tier', 'CTR', 'CPC', 'conversion_rate',
#        'CPA', 'ROAS', 'profit'],
#       dtype='str')

# %%
attribution.info()
performance.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User ID     10000 non-null  int64
#  1   Timestamp   10000 non-null  str
#  2   Channel     10000 non-null  str
#  3   Campaign    10000 non-null  str
#  4   Conversion  10000 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 390.8 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   campaign_id                   10000 non-null  str
#  1   campaign_objective            10000 non-null  str
#  2   platform                      10000 non-null  str
#  3   ad_placement                  10000 non-null  str
#  4   device_type                   10000 non-null  str
#  5   operating_system              10000 non-null  str
# ...
